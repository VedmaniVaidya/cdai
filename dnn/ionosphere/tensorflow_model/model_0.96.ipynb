# %%
# Python built-in module
import warnings

# Third-party modules
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow.keras import Input, Sequential
from tensorflow.keras.layers import BatchNormalization, Dense, Dropout, LeakyReLU
import matplotlib.pyplot as plt
import seaborn as sns
from dataclasses import dataclass
from pathlib import Path

from typing import Tuple

# Set random seed and enable operation determinism
tf.keras.utils.set_random_seed(42)
tf.config.experimental.enable_op_determinism()

# Ignore warnings
warnings.filterwarnings("ignore")
# Out:
# 2023-11-29 13:33:33.468179: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-29 13:33:33.530363: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-29 13:33:33.530406: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-29 13:33:33.531771: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-29 13:33:33.541052: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-29 13:33:34.471544: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
def prepare_data(df: pd.DataFrame) -> Tuple[np.ndarray, np.ndarray, StandardScaler]:
    # Drop the first column from the dataframe
    df.drop(1, axis=1, inplace=True)
    
    # Initialize a label encoder
    encoder = LabelEncoder()
    
    # Fit and transform the 34th column with the label encoder
    df[34] = encoder.fit_transform(df[34])
    
    # Separate the features (X) and the target variable (y)
    X = df.drop(34, axis=1)
    y = df[34]
    
    # Initialize a standard scaler
    scaler = StandardScaler()
    
    # Fit and transform the features with the standard scaler
    X = scaler.fit_transform(X)
    
    # Return the scaled features, the target variable, and the scaler
    return X, y, scaler

# %%
# Load the dataset
df = pd.read_csv('data/ionosphere.data', header=None)
# Prepare the dataset
X,y, scaler = prepare_data(df)
print(X.shape, y.shape)
# Out:
# (351, 33) (351,)

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X,y, stratify=y, random_state=42, shuffle=True)

# %%
@dataclass
class Params:
    input_dim: int = X.shape[1]  # Input dimension based on features
    output_dim: int = 1  # Output dimension (binary classification)
    dropout: float = 0.5  # Dropout rate for regularization
    learning_rate: float = 0.001  # Learning rate for optimizer
    epochs: int = 150  # Number of training epochs
    batch_size: int = 32  # Batch size for training
    save_dir: str = Path('checkpoints')  # Directory to save model checkpoints
    save_path: str = save_dir/'model.h5'  # Path to save the model
    verbose: int = 1  # Verbosity mode

    # Create directory if it doesn't exist
    save_dir.mkdir(parents=True, exist_ok=True)

# Create an instance of Params
params = Params()

# %%
def create_model(input_size, hidden_size, num_classes, dropout_rate=0.3):
    # Initialize a Sequential model
    model = Sequential([
        # First hidden layer with 'hidden_size*2' neurons, and input dimensionality as 'input_size'
        Dense(hidden_size*2, input_dim=input_size,),
        # Apply LeakyReLU activation function
        LeakyReLU(),
        # Normalize the activations of the previous layer at each batch
        BatchNormalization(),
        
        # Second hidden layer with 'hidden_size*2' neurons
        Dense(hidden_size*2),
        # Apply LeakyReLU activation function
        LeakyReLU(),
        # Normalize the activations of the previous layer at each batch
        BatchNormalization(),
        
        # Third hidden layer with 'hidden_size' neurons
        Dense(hidden_size),
        # Apply LeakyReLU activation function
        LeakyReLU(),
        # Normalize the activations of the previous layer at each batch
        BatchNormalization(),

        # Apply dropout with rate 'dropout_rate' to prevent overfitting
        Dropout(dropout_rate),

        # Fourth hidden layer with 'hidden_size' neurons
        Dense(hidden_size),
        # Apply LeakyReLU activation function
        LeakyReLU(),
        # Normalize the activations of the previous layer at each batch
        BatchNormalization(),
        
        # Apply dropout with rate 'dropout_rate' to prevent overfitting
        Dropout(dropout_rate),
        
        # Output layer with 'num_classes' neurons and linear activation function
        Dense(num_classes, activation='sigmoid')
    ])
    
    # Return the constructed model
    return model

# %%
model = create_model(input_size = params.input_dim,hidden_size=20,num_classes=params.output_dim, dropout_rate=params.dropout)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 40)                1360
#
#  leaky_re_lu (LeakyReLU)     (None, 40)                0
#
#  batch_normalization (Batch  (None, 40)                160
#  Normalization)
#
#  dense_1 (Dense)             (None, 40)                1640
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 40)                0
#
#  batch_normalization_1 (Bat  (None, 40)                160
#  chNormalization)
#
#  dense_2 (Dense)             (None, 20)                820
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 20)                0
#
#  batch_normalization_2 (Bat  (None, 20)                80
#  chNormalization)
#
#  dropout (Dropout)           (None, 20)                0
#
#  dense_3 (Dense)             (None, 20)                420
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 20)                0
#
#  batch_normalization_3 (Bat  (None, 20)                80
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense_4 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 4741 (18.52 KB)
# Trainable params: 4501 (17.58 KB)
# Non-trainable params: 240 (960.00 Byte)
# _________________________________________________________________

# %%
# Binary Crossentropy loss function
loss = tf.keras.losses.BinaryCrossentropy(from_logits=False)

# Adam optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=params.learning_rate)

# Learning rate schedule
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=params.learning_rate,
    decay_steps=10000,
    decay_rate=0.96,
    staircase=True)

# Assign schedule to optimizer
optimizer.learning_rate = lr_schedule

# Metrics for training monitoring
metrics = ['accuracy', tf.keras.metrics.AUC()]

# Callback to save best model
checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
    str(params.save_path),
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=params.verbose,)

# Callback for early stopping
early_stopping_cb = tf.keras.callbacks.EarlyStopping(
    monitor='val_auc',
    patience=30,
    restore_best_weights=True,
    mode='max',
    verbose=params.verbose,)

# Callback to reduce learning rate on plateau
reduce_lr_cb = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    patience=5,
    verbose=params.verbose,)

# List of callbacks
# callbacks = [reduce_lr_cb, checkpoint_cb]
callbacks = [early_stopping_cb, reduce_lr_cb, checkpoint_cb]

# Compile the model
model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

# %%
# Fit the model
hist = model.fit(X_train, y_train, callbacks=callbacks, validation_data=(X_test, y_test), epochs=params.epochs, batch_size=params.batch_size)
# Out:
# Epoch 1/150
# 9/9 [==============================] - ETA: 0s - loss: 0.9731 - accuracy: 0.4981 - auc: 0.4838
# Epoch 1: val_loss improved from inf to 0.67444, saving model to checkpoints/model.h5
# 9/9 [==============================] - 5s 145ms/step - loss: 0.9731 - accuracy: 0.4981 - auc: 0.4838 - val_loss: 0.6744 - val_accuracy: 0.7159 - val_auc: 0.7553 - lr: 0.0010
# Epoch 2/150
# 9/9 [==============================] - ETA: 0s - loss: 0.8106 - accuracy: 0.6160 - auc: 0.6184
# Epoch 2: val_loss improved from 0.67444 to 0.63230, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 26ms/step - loss: 0.8106 - accuracy: 0.6160 - auc: 0.6184 - val_loss: 0.6323 - val_accuracy: 0.8068 - val_auc: 0.8198 - lr: 0.0010
# Epoch 3/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.6258 - accuracy: 0.6250 - auc: 0.6000
# Epoch 3: val_loss improved from 0.63230 to 0.58665, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 29ms/step - loss: 0.7657 - accuracy: 0.6464 - auc: 0.6571 - val_loss: 0.5867 - val_accuracy: 0.8295 - val_auc: 0.8756 - lr: 0.0010
# Epoch 4/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.8373 - accuracy: 0.6562 - auc: 0.6548
# Epoch 4: val_loss improved from 0.58665 to 0.54232, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6412 - accuracy: 0.7034 - auc: 0.7387 - val_loss: 0.5423 - val_accuracy: 0.8636 - val_auc: 0.9043 - lr: 0.0010
# Epoch 5/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.5552 - accuracy: 0.7500 - auc: 0.8196
# Epoch 5: val_loss improved from 0.54232 to 0.49859, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 26ms/step - loss: 0.5593 - accuracy: 0.7605 - auc: 0.7770 - val_loss: 0.4986 - val_accuracy: 0.8977 - val_auc: 0.9336 - lr: 0.0010
# Epoch 6/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.6365 - accuracy: 0.6562 - auc: 0.6970
# Epoch 6: val_loss improved from 0.49859 to 0.46456, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 26ms/step - loss: 0.5335 - accuracy: 0.7414 - auc: 0.7843 - val_loss: 0.4646 - val_accuracy: 0.9318 - val_auc: 0.9428 - lr: 0.0010
# Epoch 7/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.5147 - accuracy: 0.8125 - auc: 0.7771
# Epoch 7: val_loss improved from 0.46456 to 0.44071, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 27ms/step - loss: 0.4499 - accuracy: 0.7985 - auc: 0.8501 - val_loss: 0.4407 - val_accuracy: 0.9432 - val_auc: 0.9434 - lr: 0.0010
# Epoch 8/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.5094 - accuracy: 0.6875 - auc: 0.7708
# Epoch 8: val_loss improved from 0.44071 to 0.41113, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 24ms/step - loss: 0.5368 - accuracy: 0.7529 - auc: 0.8000 - val_loss: 0.4111 - val_accuracy: 0.9432 - val_auc: 0.9478 - lr: 0.0010
# Epoch 9/150
# 9/9 [==============================] - ETA: 0s - loss: 0.4567 - accuracy: 0.7947 - auc: 0.8536
# Epoch 9: val_loss improved from 0.41113 to 0.37708, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 25ms/step - loss: 0.4567 - accuracy: 0.7947 - auc: 0.8536 - val_loss: 0.3771 - val_accuracy: 0.9432 - val_auc: 0.9489 - lr: 0.0010
# Epoch 10/150
# 9/9 [==============================] - ETA: 0s - loss: 0.4715 - accuracy: 0.8099 - auc: 0.8386
# Epoch 10: val_loss improved from 0.37708 to 0.35241, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 26ms/step - loss: 0.4715 - accuracy: 0.8099 - auc: 0.8386 - val_loss: 0.3524 - val_accuracy: 0.9432 - val_auc: 0.9492 - lr: 0.0010
# Epoch 11/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.2319 - accuracy: 0.8750 - auc: 0.9827
# Epoch 11: val_loss improved from 0.35241 to 0.32744, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 29ms/step - loss: 0.3973 - accuracy: 0.8403 - auc: 0.8911 - val_loss: 0.3274 - val_accuracy: 0.9432 - val_auc: 0.9492 - lr: 0.0010
# Epoch 12/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.3877 - accuracy: 0.8438 - auc: 0.9245
# Epoch 12: val_loss improved from 0.32744 to 0.30684, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 27ms/step - loss: 0.3901 - accuracy: 0.8403 - auc: 0.9028 - val_loss: 0.3068 - val_accuracy: 0.9432 - val_auc: 0.9487 - lr: 0.0010
# Epoch 13/150
# 9/9 [==============================] - ETA: 0s - loss: 0.3642 - accuracy: 0.8555 - auc: 0.9024
# Epoch 13: val_loss improved from 0.30684 to 0.29201, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 26ms/step - loss: 0.3642 - accuracy: 0.8555 - auc: 0.9024 - val_loss: 0.2920 - val_accuracy: 0.9432 - val_auc: 0.9464 - lr: 0.0010
# Epoch 14/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.3068 - accuracy: 0.9062 - auc: 0.9504
# Epoch 14: val_loss improved from 0.29201 to 0.27779, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 26ms/step - loss: 0.4307 - accuracy: 0.8213 - auc: 0.8693 - val_loss: 0.2778 - val_accuracy: 0.9432 - val_auc: 0.9448 - lr: 0.0010
# Epoch 15/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.2758 - accuracy: 0.9062 - auc: 0.9643
# Epoch 15: val_loss improved from 0.27779 to 0.26504, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 24ms/step - loss: 0.3481 - accuracy: 0.8707 - auc: 0.9106 - val_loss: 0.2650 - val_accuracy: 0.9318 - val_auc: 0.9456 - lr: 0.0010
# Epoch 16/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.3106 - accuracy: 0.8438 - auc: 0.9500
# Epoch 16: val_loss improved from 0.26504 to 0.25469, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 22ms/step - loss: 0.2702 - accuracy: 0.9049 - auc: 0.9562 - val_loss: 0.2547 - val_accuracy: 0.9318 - val_auc: 0.9459 - lr: 0.0010
# Epoch 17/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.4619 - accuracy: 0.7812 - auc: 0.9034
# Epoch 17: val_loss improved from 0.25469 to 0.24969, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 23ms/step - loss: 0.3657 - accuracy: 0.8517 - auc: 0.9204 - val_loss: 0.2497 - val_accuracy: 0.9318 - val_auc: 0.9381 - lr: 0.0010
# Epoch 18/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.3650 - accuracy: 0.8750 - auc: 0.9000
# Epoch 18: val_loss improved from 0.24969 to 0.24954, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 25ms/step - loss: 0.3232 - accuracy: 0.8707 - auc: 0.9202 - val_loss: 0.2495 - val_accuracy: 0.9318 - val_auc: 0.9325 - lr: 0.0010
# Epoch 19/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.2717 - accuracy: 0.9062 - auc: 0.9855
# Epoch 19: val_loss did not improve from 0.24954
# 9/9 [==============================] - 0s 16ms/step - loss: 0.3170 - accuracy: 0.8897 - auc: 0.9298 - val_loss: 0.2513 - val_accuracy: 0.9205 - val_auc: 0.9269 - lr: 0.0010
# Epoch 20/150
# 9/9 [==============================] - ETA: 0s - loss: 0.2663 - accuracy: 0.8897 - auc: 0.9567
# Epoch 20: val_loss improved from 0.24954 to 0.24763, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 30ms/step - loss: 0.2663 - accuracy: 0.8897 - auc: 0.9567 - val_loss: 0.2476 - val_accuracy: 0.9205 - val_auc: 0.9280 - lr: 0.0010
# Epoch 21/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1968 - accuracy: 0.9688 - auc: 1.0000
# Epoch 21: val_loss improved from 0.24763 to 0.24271, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 25ms/step - loss: 0.2540 - accuracy: 0.8973 - auc: 0.9634 - val_loss: 0.2427 - val_accuracy: 0.9205 - val_auc: 0.9325 - lr: 0.0010
# Epoch 22/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.2944 - accuracy: 0.9062 - auc: 0.9500
# Epoch 22: val_loss improved from 0.24271 to 0.23967, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 24ms/step - loss: 0.2736 - accuracy: 0.9011 - auc: 0.9449 - val_loss: 0.2397 - val_accuracy: 0.9318 - val_auc: 0.9339 - lr: 0.0010
# Epoch 23/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.3366 - accuracy: 0.8125 - auc: 0.9221
# Epoch 23: val_loss improved from 0.23967 to 0.23358, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 25ms/step - loss: 0.2926 - accuracy: 0.8821 - auc: 0.9450 - val_loss: 0.2336 - val_accuracy: 0.9318 - val_auc: 0.9339 - lr: 0.0010
# Epoch 24/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.3101 - accuracy: 0.8438 - auc: 0.9940
# Epoch 24: val_loss improved from 0.23358 to 0.23188, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 27ms/step - loss: 0.2610 - accuracy: 0.9202 - auc: 0.9529 - val_loss: 0.2319 - val_accuracy: 0.9205 - val_auc: 0.9342 - lr: 0.0010
# Epoch 25/150
# 9/9 [==============================] - ETA: 0s - loss: 0.2694 - accuracy: 0.9087 - auc: 0.9537
# Epoch 25: val_loss improved from 0.23188 to 0.23174, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 25ms/step - loss: 0.2694 - accuracy: 0.9087 - auc: 0.9537 - val_loss: 0.2317 - val_accuracy: 0.9205 - val_auc: 0.9342 - lr: 0.0010
# Epoch 26/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.2261 - accuracy: 0.9688 - auc: 0.9416
# Epoch 26: val_loss improved from 0.23174 to 0.22608, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 25ms/step - loss: 0.2434 - accuracy: 0.9163 - auc: 0.9619 - val_loss: 0.2261 - val_accuracy: 0.9205 - val_auc: 0.9372 - lr: 0.0010
# Epoch 27/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.2291 - accuracy: 0.9375 - auc: 0.9610
# Epoch 27: val_loss improved from 0.22608 to 0.22261, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 27ms/step - loss: 0.2544 - accuracy: 0.9049 - auc: 0.9563 - val_loss: 0.2226 - val_accuracy: 0.9318 - val_auc: 0.9358 - lr: 0.0010
# Epoch 28/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1739 - accuracy: 0.9062 - auc: 0.9909
# Epoch 28: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 16ms/step - loss: 0.2388 - accuracy: 0.9125 - auc: 0.9608 - val_loss: 0.2275 - val_accuracy: 0.9205 - val_auc: 0.9336 - lr: 0.0010
# Epoch 29/150
# 8/9 [=========================>....] - ETA: 0s - loss: 0.2121 - accuracy: 0.9297 - auc: 0.9732
# Epoch 29: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2241 - accuracy: 0.9278 - auc: 0.9656 - val_loss: 0.2326 - val_accuracy: 0.9205 - val_auc: 0.9333 - lr: 0.0010
# Epoch 30/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.2560 - accuracy: 0.8750 - auc: 0.9717
# Epoch 30: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1820 - accuracy: 0.9392 - auc: 0.9848 - val_loss: 0.2332 - val_accuracy: 0.9205 - val_auc: 0.9336 - lr: 0.0010
# Epoch 31/150
# 9/9 [==============================] - ETA: 0s - loss: 0.2187 - accuracy: 0.9316 - auc: 0.9675
# Epoch 31: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.2187 - accuracy: 0.9316 - auc: 0.9675 - val_loss: 0.2382 - val_accuracy: 0.9205 - val_auc: 0.9330 - lr: 0.0010
# Epoch 32/150
# 8/9 [=========================>....] - ETA: 0s - loss: 0.2194 - accuracy: 0.9219 - auc: 0.9672
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 32: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.2164 - accuracy: 0.9240 - auc: 0.9679 - val_loss: 0.2395 - val_accuracy: 0.9205 - val_auc: 0.9302 - lr: 0.0010
# Epoch 33/150
# 9/9 [==============================] - ETA: 0s - loss: 0.2258 - accuracy: 0.9049 - auc: 0.9657
# Epoch 33: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2258 - accuracy: 0.9049 - auc: 0.9657 - val_loss: 0.2399 - val_accuracy: 0.9205 - val_auc: 0.9302 - lr: 0.0010
# Epoch 34/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1978 - accuracy: 0.9354 - auc: 0.9772
# Epoch 34: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 19ms/step - loss: 0.1978 - accuracy: 0.9354 - auc: 0.9772 - val_loss: 0.2322 - val_accuracy: 0.9318 - val_auc: 0.9311 - lr: 0.0010
# Epoch 35/150
# 9/9 [==============================] - ETA: 0s - loss: 0.2272 - accuracy: 0.9125 - auc: 0.9591
# Epoch 35: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2272 - accuracy: 0.9125 - auc: 0.9591 - val_loss: 0.2379 - val_accuracy: 0.9318 - val_auc: 0.9314 - lr: 0.0010
# Epoch 36/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.2792 - accuracy: 0.9062 - auc: 0.9636
# Epoch 36: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1745 - accuracy: 0.9430 - auc: 0.9808 - val_loss: 0.2361 - val_accuracy: 0.9318 - val_auc: 0.9316 - lr: 0.0010
# Epoch 37/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1258 - accuracy: 0.9688 - auc: 1.0000
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 37: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 16ms/step - loss: 0.2034 - accuracy: 0.9354 - auc: 0.9742 - val_loss: 0.2323 - val_accuracy: 0.9318 - val_auc: 0.9369 - lr: 0.0010
# Epoch 38/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1857 - accuracy: 0.9125 - auc: 0.9818
# Epoch 38: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1857 - accuracy: 0.9125 - auc: 0.9818 - val_loss: 0.2291 - val_accuracy: 0.9318 - val_auc: 0.9369 - lr: 0.0010
# Epoch 39/150
# 9/9 [==============================] - ETA: 0s - loss: 0.2106 - accuracy: 0.9278 - auc: 0.9678
# Epoch 39: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.2106 - accuracy: 0.9278 - auc: 0.9678 - val_loss: 0.2312 - val_accuracy: 0.9318 - val_auc: 0.9361 - lr: 0.0010
# Epoch 40/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1774 - accuracy: 0.9278 - auc: 0.9844
# Epoch 40: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 19ms/step - loss: 0.1774 - accuracy: 0.9278 - auc: 0.9844 - val_loss: 0.2283 - val_accuracy: 0.9318 - val_auc: 0.9383 - lr: 0.0010
# Epoch 41/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1798 - accuracy: 0.9062 - auc: 0.9917
# Epoch 41: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1761 - accuracy: 0.9278 - auc: 0.9846 - val_loss: 0.2320 - val_accuracy: 0.9318 - val_auc: 0.9386 - lr: 0.0010
# Epoch 42/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1742 - accuracy: 0.9430 - auc: 0.9803
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 42: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1742 - accuracy: 0.9430 - auc: 0.9803 - val_loss: 0.2328 - val_accuracy: 0.9318 - val_auc: 0.9417 - lr: 0.0010
# Epoch 43/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1891 - accuracy: 0.9354 - auc: 0.9744
# Epoch 43: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1891 - accuracy: 0.9354 - auc: 0.9744 - val_loss: 0.2325 - val_accuracy: 0.9318 - val_auc: 0.9448 - lr: 0.0010
# Epoch 44/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1705 - accuracy: 0.9354 - auc: 0.9848
# Epoch 44: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1705 - accuracy: 0.9354 - auc: 0.9848 - val_loss: 0.2352 - val_accuracy: 0.9205 - val_auc: 0.9467 - lr: 0.0010
# Epoch 45/150
# 8/9 [=========================>....] - ETA: 0s - loss: 0.2068 - accuracy: 0.9453 - auc: 0.9718
# Epoch 45: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2222 - accuracy: 0.9392 - auc: 0.9676 - val_loss: 0.2328 - val_accuracy: 0.9205 - val_auc: 0.9459 - lr: 0.0010
# Epoch 46/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1480 - accuracy: 0.9688 - auc: 0.9870
# Epoch 46: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 16ms/step - loss: 0.1590 - accuracy: 0.9354 - auc: 0.9874 - val_loss: 0.2377 - val_accuracy: 0.9205 - val_auc: 0.9425 - lr: 0.0010
# Epoch 47/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1986 - accuracy: 0.9240 - auc: 0.9756
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 47: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1986 - accuracy: 0.9240 - auc: 0.9756 - val_loss: 0.2347 - val_accuracy: 0.9318 - val_auc: 0.9450 - lr: 0.0010
# Epoch 48/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1626 - accuracy: 0.9354 - auc: 0.9830
# Epoch 48: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1626 - accuracy: 0.9354 - auc: 0.9830 - val_loss: 0.2378 - val_accuracy: 0.9318 - val_auc: 0.9403 - lr: 0.0010
# Epoch 49/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1349 - accuracy: 0.9582 - auc: 0.9867
# Epoch 49: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1349 - accuracy: 0.9582 - auc: 0.9867 - val_loss: 0.2334 - val_accuracy: 0.9318 - val_auc: 0.9428 - lr: 0.0010
# Epoch 50/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1708 - accuracy: 0.9506 - auc: 0.9842
# Epoch 50: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1708 - accuracy: 0.9506 - auc: 0.9842 - val_loss: 0.2316 - val_accuracy: 0.9318 - val_auc: 0.9456 - lr: 0.0010
# Epoch 51/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1370 - accuracy: 0.9544 - auc: 0.9905
# Epoch 51: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1370 - accuracy: 0.9544 - auc: 0.9905 - val_loss: 0.2330 - val_accuracy: 0.9318 - val_auc: 0.9414 - lr: 0.0010
# Epoch 52/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1391 - accuracy: 0.9582 - auc: 0.9898
# Epoch 52: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 52: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1391 - accuracy: 0.9582 - auc: 0.9898 - val_loss: 0.2375 - val_accuracy: 0.9318 - val_auc: 0.9353 - lr: 0.0010
# Epoch 53/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1852 - accuracy: 0.9354 - auc: 0.9754
# Epoch 53: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1852 - accuracy: 0.9354 - auc: 0.9754 - val_loss: 0.2410 - val_accuracy: 0.9318 - val_auc: 0.9364 - lr: 0.0010
# Epoch 54/150
# 8/9 [=========================>....] - ETA: 0s - loss: 0.1447 - accuracy: 0.9648 - auc: 0.9844
# Epoch 54: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1463 - accuracy: 0.9658 - auc: 0.9845 - val_loss: 0.2412 - val_accuracy: 0.9318 - val_auc: 0.9389 - lr: 0.0010
# Epoch 55/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1491 - accuracy: 0.9506 - auc: 0.9867
# Epoch 55: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 20ms/step - loss: 0.1491 - accuracy: 0.9506 - auc: 0.9867 - val_loss: 0.2475 - val_accuracy: 0.9205 - val_auc: 0.9411 - lr: 0.0010
# Epoch 56/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1328 - accuracy: 0.9620 - auc: 0.9860
# Epoch 56: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1328 - accuracy: 0.9620 - auc: 0.9860 - val_loss: 0.2464 - val_accuracy: 0.9318 - val_auc: 0.9361 - lr: 0.0010
# Epoch 57/150
# 9/9 [==============================] - ETA: 0s - loss: 0.2252 - accuracy: 0.9125 - auc: 0.9576
# Epoch 57: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 57: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2252 - accuracy: 0.9125 - auc: 0.9576 - val_loss: 0.2516 - val_accuracy: 0.9318 - val_auc: 0.9358 - lr: 0.0010
# Epoch 58/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1650 - accuracy: 0.9354 - auc: 0.9809
# Epoch 58: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1650 - accuracy: 0.9354 - auc: 0.9809 - val_loss: 0.2358 - val_accuracy: 0.9318 - val_auc: 0.9434 - lr: 0.0010
# Epoch 59/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1554 - accuracy: 0.9582 - auc: 0.9835
# Epoch 59: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1554 - accuracy: 0.9582 - auc: 0.9835 - val_loss: 0.2322 - val_accuracy: 0.9318 - val_auc: 0.9420 - lr: 0.0010
# Epoch 60/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1784 - accuracy: 0.9316 - auc: 0.9808
# Epoch 60: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1784 - accuracy: 0.9316 - auc: 0.9808 - val_loss: 0.2417 - val_accuracy: 0.9432 - val_auc: 0.9386 - lr: 0.0010
# Epoch 61/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1425 - accuracy: 0.9658 - auc: 0.9828
# Epoch 61: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1425 - accuracy: 0.9658 - auc: 0.9828 - val_loss: 0.2474 - val_accuracy: 0.9318 - val_auc: 0.9400 - lr: 0.0010
# Epoch 62/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1431 - accuracy: 0.9392 - auc: 0.9894
# Epoch 62: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 62: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1431 - accuracy: 0.9392 - auc: 0.9894 - val_loss: 0.2531 - val_accuracy: 0.9432 - val_auc: 0.9453 - lr: 0.0010
# Epoch 63/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1320 - accuracy: 0.9544 - auc: 0.9899
# Epoch 63: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 19ms/step - loss: 0.1320 - accuracy: 0.9544 - auc: 0.9899 - val_loss: 0.2554 - val_accuracy: 0.9432 - val_auc: 0.9473 - lr: 0.0010
# Epoch 64/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1210 - accuracy: 0.9544 - auc: 0.9907
# Epoch 64: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1210 - accuracy: 0.9544 - auc: 0.9907 - val_loss: 0.2629 - val_accuracy: 0.9318 - val_auc: 0.9475 - lr: 0.0010
# Epoch 65/150
# 9/9 [==============================] - ETA: 0s - loss: 0.2492 - accuracy: 0.9049 - auc: 0.9636
# Epoch 65: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2492 - accuracy: 0.9049 - auc: 0.9636 - val_loss: 0.2721 - val_accuracy: 0.9205 - val_auc: 0.9484 - lr: 0.0010
# Epoch 66/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1845 - accuracy: 0.9163 - auc: 0.9783
# Epoch 66: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1845 - accuracy: 0.9163 - auc: 0.9783 - val_loss: 0.2702 - val_accuracy: 0.9205 - val_auc: 0.9475 - lr: 0.0010
# Epoch 67/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1868 - accuracy: 0.9375 - auc: 0.9792
# Epoch 67: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 67: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1199 - accuracy: 0.9582 - auc: 0.9937 - val_loss: 0.2678 - val_accuracy: 0.9318 - val_auc: 0.9481 - lr: 0.0010
# Epoch 68/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1723 - accuracy: 0.9375 - auc: 0.9948
# Epoch 68: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 16ms/step - loss: 0.1814 - accuracy: 0.9430 - auc: 0.9791 - val_loss: 0.2599 - val_accuracy: 0.9318 - val_auc: 0.9478 - lr: 0.0010
# Epoch 69/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1347 - accuracy: 0.9582 - auc: 0.9867
# Epoch 69: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1347 - accuracy: 0.9582 - auc: 0.9867 - val_loss: 0.2605 - val_accuracy: 0.9432 - val_auc: 0.9470 - lr: 0.0010
# Epoch 70/150
# 9/9 [==============================] - ETA: 0s - loss: 0.0994 - accuracy: 0.9810 - auc: 0.9918
# Epoch 70: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0994 - accuracy: 0.9810 - auc: 0.9918 - val_loss: 0.2618 - val_accuracy: 0.9318 - val_auc: 0.9383 - lr: 0.0010
# Epoch 71/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1552 - accuracy: 0.9375 - auc: 0.9864
# Epoch 71: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1375 - accuracy: 0.9430 - auc: 0.9890 - val_loss: 0.2564 - val_accuracy: 0.9318 - val_auc: 0.9487 - lr: 0.0010
# Epoch 72/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1676 - accuracy: 0.9430 - auc: 0.9822
# Epoch 72: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 72: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1676 - accuracy: 0.9430 - auc: 0.9822 - val_loss: 0.2516 - val_accuracy: 0.9318 - val_auc: 0.9548 - lr: 0.0010
# Epoch 73/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1883 - accuracy: 0.9163 - auc: 0.9754
# Epoch 73: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1883 - accuracy: 0.9163 - auc: 0.9754 - val_loss: 0.2587 - val_accuracy: 0.9318 - val_auc: 0.9448 - lr: 0.0010
# Epoch 74/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1774 - accuracy: 0.9392 - auc: 0.9799
# Epoch 74: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1774 - accuracy: 0.9392 - auc: 0.9799 - val_loss: 0.2428 - val_accuracy: 0.9318 - val_auc: 0.9489 - lr: 0.0010
# Epoch 75/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1245 - accuracy: 0.9468 - auc: 0.9922
# Epoch 75: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1245 - accuracy: 0.9468 - auc: 0.9922 - val_loss: 0.2378 - val_accuracy: 0.9318 - val_auc: 0.9548 - lr: 0.0010
# Epoch 76/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1107 - accuracy: 0.9506 - auc: 0.9933
# Epoch 76: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1107 - accuracy: 0.9506 - auc: 0.9933 - val_loss: 0.2337 - val_accuracy: 0.9318 - val_auc: 0.9595 - lr: 0.0010
# Epoch 77/150
# 9/9 [==============================] - ETA: 0s - loss: 0.0989 - accuracy: 0.9734 - auc: 0.9947
# Epoch 77: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 77: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0989 - accuracy: 0.9734 - auc: 0.9947 - val_loss: 0.2271 - val_accuracy: 0.9318 - val_auc: 0.9640 - lr: 0.0010
# Epoch 78/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1566 - accuracy: 0.9658 - auc: 0.9818
# Epoch 78: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1566 - accuracy: 0.9658 - auc: 0.9818 - val_loss: 0.2304 - val_accuracy: 0.9318 - val_auc: 0.9646 - lr: 0.0010
# Epoch 79/150
# 9/9 [==============================] - ETA: 0s - loss: 0.0999 - accuracy: 0.9772 - auc: 0.9972
# Epoch 79: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0999 - accuracy: 0.9772 - auc: 0.9972 - val_loss: 0.2336 - val_accuracy: 0.9318 - val_auc: 0.9660 - lr: 0.0010
# Epoch 80/150
# 8/9 [=========================>....] - ETA: 0s - loss: 0.0988 - accuracy: 0.9688 - auc: 0.9957
# Epoch 80: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 15ms/step - loss: 0.1008 - accuracy: 0.9696 - auc: 0.9955 - val_loss: 0.2452 - val_accuracy: 0.9318 - val_auc: 0.9609 - lr: 0.0010
# Epoch 81/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1384 - accuracy: 0.9658 - auc: 0.9800
# Epoch 81: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1384 - accuracy: 0.9658 - auc: 0.9800 - val_loss: 0.2551 - val_accuracy: 0.9318 - val_auc: 0.9604 - lr: 0.0010
# Epoch 82/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1388 - accuracy: 0.9544 - auc: 0.9889
# Epoch 82: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 82: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1388 - accuracy: 0.9544 - auc: 0.9889 - val_loss: 0.2582 - val_accuracy: 0.9318 - val_auc: 0.9526 - lr: 0.0010
# Epoch 83/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1055 - accuracy: 0.9658 - auc: 0.9928
# Epoch 83: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1055 - accuracy: 0.9658 - auc: 0.9928 - val_loss: 0.2560 - val_accuracy: 0.9318 - val_auc: 0.9540 - lr: 0.0010
# Epoch 84/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1530 - accuracy: 0.9468 - auc: 0.9838
# Epoch 84: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1530 - accuracy: 0.9468 - auc: 0.9838 - val_loss: 0.2482 - val_accuracy: 0.9318 - val_auc: 0.9537 - lr: 0.0010
# Epoch 85/150
# 9/9 [==============================] - ETA: 0s - loss: 0.0947 - accuracy: 0.9658 - auc: 0.9956
# Epoch 85: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0947 - accuracy: 0.9658 - auc: 0.9956 - val_loss: 0.2460 - val_accuracy: 0.9318 - val_auc: 0.9537 - lr: 0.0010
# Epoch 86/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1641 - accuracy: 0.9240 - auc: 0.9848
# Epoch 86: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1641 - accuracy: 0.9240 - auc: 0.9848 - val_loss: 0.2410 - val_accuracy: 0.9318 - val_auc: 0.9523 - lr: 0.0010
# Epoch 87/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1143 - accuracy: 0.9620 - auc: 0.9936
# Epoch 87: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 87: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1143 - accuracy: 0.9620 - auc: 0.9936 - val_loss: 0.2346 - val_accuracy: 0.9318 - val_auc: 0.9512 - lr: 0.0010
# Epoch 88/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1151 - accuracy: 0.9620 - auc: 0.9914
# Epoch 88: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1151 - accuracy: 0.9620 - auc: 0.9914 - val_loss: 0.2272 - val_accuracy: 0.9318 - val_auc: 0.9515 - lr: 0.0010
# Epoch 89/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1380 - accuracy: 0.9544 - auc: 0.9844
# Epoch 89: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1380 - accuracy: 0.9544 - auc: 0.9844 - val_loss: 0.2282 - val_accuracy: 0.9318 - val_auc: 0.9545 - lr: 0.0010
# Epoch 90/150
# 8/9 [=========================>....] - ETA: 0s - loss: 0.1016 - accuracy: 0.9688 - auc: 0.9941
# Epoch 90: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1016 - accuracy: 0.9696 - auc: 0.9944 - val_loss: 0.2240 - val_accuracy: 0.9318 - val_auc: 0.9542 - lr: 0.0010
# Epoch 91/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.0543 - accuracy: 0.9688 - auc: 1.0000
# Epoch 91: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 15ms/step - loss: 0.1112 - accuracy: 0.9620 - auc: 0.9885 - val_loss: 0.2305 - val_accuracy: 0.9318 - val_auc: 0.9542 - lr: 0.0010
# Epoch 92/150
# 9/9 [==============================] - ETA: 0s - loss: 0.0870 - accuracy: 0.9734 - auc: 0.9961
# Epoch 92: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 92: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0870 - accuracy: 0.9734 - auc: 0.9961 - val_loss: 0.2324 - val_accuracy: 0.9318 - val_auc: 0.9548 - lr: 0.0010
# Epoch 93/150
# 9/9 [==============================] - ETA: 0s - loss: 0.0970 - accuracy: 0.9620 - auc: 0.9954
# Epoch 93: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0970 - accuracy: 0.9620 - auc: 0.9954 - val_loss: 0.2394 - val_accuracy: 0.9318 - val_auc: 0.9545 - lr: 0.0010
# Epoch 94/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1230 - accuracy: 0.9620 - auc: 0.9913
# Epoch 94: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1230 - accuracy: 0.9620 - auc: 0.9913 - val_loss: 0.2377 - val_accuracy: 0.9432 - val_auc: 0.9548 - lr: 0.0010
# Epoch 95/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1014 - accuracy: 0.9734 - auc: 0.9935
# Epoch 95: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 19ms/step - loss: 0.1014 - accuracy: 0.9734 - auc: 0.9935 - val_loss: 0.2310 - val_accuracy: 0.9432 - val_auc: 0.9554 - lr: 0.0010
# Epoch 96/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1466 - accuracy: 0.9544 - auc: 0.9869
# Epoch 96: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1466 - accuracy: 0.9544 - auc: 0.9869 - val_loss: 0.2303 - val_accuracy: 0.9432 - val_auc: 0.9576 - lr: 0.0010
# Epoch 97/150
# 9/9 [==============================] - ETA: 0s - loss: 0.0933 - accuracy: 0.9734 - auc: 0.9944
# Epoch 97: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 97: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0933 - accuracy: 0.9734 - auc: 0.9944 - val_loss: 0.2347 - val_accuracy: 0.9432 - val_auc: 0.9576 - lr: 0.0010
# Epoch 98/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.0455 - accuracy: 1.0000 - auc: 1.0000
# Epoch 98: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 16ms/step - loss: 0.1012 - accuracy: 0.9658 - auc: 0.9932 - val_loss: 0.2340 - val_accuracy: 0.9432 - val_auc: 0.9570 - lr: 0.0010
# Epoch 99/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1344 - accuracy: 0.9506 - auc: 0.9898
# Epoch 99: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1344 - accuracy: 0.9506 - auc: 0.9898 - val_loss: 0.2336 - val_accuracy: 0.9432 - val_auc: 0.9570 - lr: 0.0010
# Epoch 100/150
# 9/9 [==============================] - ETA: 0s - loss: 0.0894 - accuracy: 0.9620 - auc: 0.9963
# Epoch 100: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0894 - accuracy: 0.9620 - auc: 0.9963 - val_loss: 0.2473 - val_accuracy: 0.9432 - val_auc: 0.9556 - lr: 0.0010
# Epoch 101/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1081 - accuracy: 0.9620 - auc: 0.9924
# Epoch 101: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1081 - accuracy: 0.9620 - auc: 0.9924 - val_loss: 0.2496 - val_accuracy: 0.9318 - val_auc: 0.9542 - lr: 0.0010
# Epoch 102/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1703 - accuracy: 0.9544 - auc: 0.9766
# Epoch 102: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 102: val_loss did not improve from 0.22261
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1703 - accuracy: 0.9544 - auc: 0.9766 - val_loss: 0.2406 - val_accuracy: 0.9432 - val_auc: 0.9559 - lr: 0.0010
# Epoch 103/150
# 9/9 [==============================] - ETA: 0s - loss: 0.0847 - accuracy: 0.9810 - auc: 0.9953
# Epoch 103: val_loss improved from 0.22261 to 0.22158, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0847 - accuracy: 0.9810 - auc: 0.9953 - val_loss: 0.2216 - val_accuracy: 0.9432 - val_auc: 0.9665 - lr: 0.0010
# Epoch 104/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1596 - accuracy: 0.9375 - auc: 1.0000
# Epoch 104: val_loss improved from 0.22158 to 0.21906, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 26ms/step - loss: 0.1392 - accuracy: 0.9468 - auc: 0.9859 - val_loss: 0.2191 - val_accuracy: 0.9545 - val_auc: 0.9671 - lr: 0.0010
# Epoch 105/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.0381 - accuracy: 1.0000 - auc: 1.0000
# Epoch 105: val_loss did not improve from 0.21906
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0996 - accuracy: 0.9734 - auc: 0.9943 - val_loss: 0.2333 - val_accuracy: 0.9432 - val_auc: 0.9520 - lr: 0.0010
# Epoch 106/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1146 - accuracy: 0.9734 - auc: 0.9874
# Epoch 106: val_loss did not improve from 0.21906
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1146 - accuracy: 0.9734 - auc: 0.9874 - val_loss: 0.2363 - val_accuracy: 0.9432 - val_auc: 0.9506 - lr: 0.0010
# Epoch 107/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1010 - accuracy: 0.9658 - auc: 0.9912
# Epoch 107: val_loss did not improve from 0.21906
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1010 - accuracy: 0.9658 - auc: 0.9912 - val_loss: 0.2376 - val_accuracy: 0.9432 - val_auc: 0.9487 - lr: 0.0010
# Epoch 108/150
# 9/9 [==============================] - ETA: 0s - loss: 0.0858 - accuracy: 0.9848 - auc: 0.9954
# Epoch 108: val_loss did not improve from 0.21906
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0858 - accuracy: 0.9848 - auc: 0.9954 - val_loss: 0.2350 - val_accuracy: 0.9432 - val_auc: 0.9503 - lr: 0.0010
# Epoch 109/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9620 - auc: 0.9946
# Epoch 109: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 109: val_loss did not improve from 0.21906
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1016 - accuracy: 0.9620 - auc: 0.9946 - val_loss: 0.2418 - val_accuracy: 0.9432 - val_auc: 0.9554 - lr: 0.0010
# Epoch 110/150
# 9/9 [==============================] - ETA: 0s - loss: 0.0929 - accuracy: 0.9582 - auc: 0.9954
# Epoch 110: val_loss did not improve from 0.21906
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0929 - accuracy: 0.9582 - auc: 0.9954 - val_loss: 0.2449 - val_accuracy: 0.9432 - val_auc: 0.9559 - lr: 0.0010
# Epoch 111/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.0538 - accuracy: 0.9688 - auc: 1.0000
# Epoch 111: val_loss did not improve from 0.21906
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0724 - accuracy: 0.9696 - auc: 0.9979 - val_loss: 0.2441 - val_accuracy: 0.9432 - val_auc: 0.9559 - lr: 0.0010
# Epoch 112/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1076 - accuracy: 0.9658 - auc: 0.9930
# Epoch 112: val_loss did not improve from 0.21906
# 9/9 [==============================] - 0s 20ms/step - loss: 0.1076 - accuracy: 0.9658 - auc: 0.9930 - val_loss: 0.2368 - val_accuracy: 0.9432 - val_auc: 0.9559 - lr: 0.0010
# Epoch 113/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.2134 - accuracy: 0.9062 - auc: 0.9948
# Epoch 113: val_loss did not improve from 0.21906
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1218 - accuracy: 0.9544 - auc: 0.9909 - val_loss: 0.2495 - val_accuracy: 0.9318 - val_auc: 0.9492 - lr: 0.0010
# Epoch 114/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.0847 - accuracy: 0.9688 - auc: 1.0000
# Epoch 114: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 114: val_loss did not improve from 0.21906
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1163 - accuracy: 0.9582 - auc: 0.9924 - val_loss: 0.2214 - val_accuracy: 0.9545 - val_auc: 0.9548 - lr: 0.0010
# Epoch 115/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1017 - accuracy: 0.9696 - auc: 0.9911
# Epoch 115: val_loss improved from 0.21906 to 0.20712, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1017 - accuracy: 0.9696 - auc: 0.9911 - val_loss: 0.2071 - val_accuracy: 0.9545 - val_auc: 0.9559 - lr: 0.0010
# Epoch 116/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1584 - accuracy: 0.9688 - auc: 1.0000
# Epoch 116: val_loss improved from 0.20712 to 0.19790, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 27ms/step - loss: 0.1170 - accuracy: 0.9620 - auc: 0.9903 - val_loss: 0.1979 - val_accuracy: 0.9545 - val_auc: 0.9565 - lr: 0.0010
# Epoch 117/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1458 - accuracy: 0.9375 - auc: 1.0000
# Epoch 117: val_loss improved from 0.19790 to 0.18347, saving model to checkpoints/model.h5
# 9/9 [==============================] - 0s 24ms/step - loss: 0.1038 - accuracy: 0.9734 - auc: 0.9929 - val_loss: 0.1835 - val_accuracy: 0.9545 - val_auc: 0.9548 - lr: 0.0010
# Epoch 118/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.0602 - accuracy: 0.9688 - auc: 1.0000
# Epoch 118: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0878 - accuracy: 0.9658 - auc: 0.9961 - val_loss: 0.1891 - val_accuracy: 0.9545 - val_auc: 0.9565 - lr: 0.0010
# Epoch 119/150
# 9/9 [==============================] - ETA: 0s - loss: 0.0805 - accuracy: 0.9696 - auc: 0.9974
# Epoch 119: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0805 - accuracy: 0.9696 - auc: 0.9974 - val_loss: 0.1957 - val_accuracy: 0.9545 - val_auc: 0.9570 - lr: 0.0010
# Epoch 120/150
# 9/9 [==============================] - ETA: 0s - loss: 0.0667 - accuracy: 0.9886 - auc: 0.9990
# Epoch 120: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0667 - accuracy: 0.9886 - auc: 0.9990 - val_loss: 0.2027 - val_accuracy: 0.9545 - val_auc: 0.9593 - lr: 0.0010
# Epoch 121/150
# 9/9 [==============================] - ETA: 0s - loss: 0.0674 - accuracy: 0.9810 - auc: 0.9978
# Epoch 121: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0674 - accuracy: 0.9810 - auc: 0.9978 - val_loss: 0.2055 - val_accuracy: 0.9545 - val_auc: 0.9587 - lr: 0.0010
# Epoch 122/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.2966 - accuracy: 0.9062 - auc: 0.9843
# Epoch 122: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 122: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 15ms/step - loss: 0.1074 - accuracy: 0.9620 - auc: 0.9905 - val_loss: 0.2088 - val_accuracy: 0.9545 - val_auc: 0.9581 - lr: 0.0010
# Epoch 123/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.0356 - accuracy: 1.0000 - auc: 1.0000
# Epoch 123: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0742 - accuracy: 0.9772 - auc: 0.9975 - val_loss: 0.2122 - val_accuracy: 0.9545 - val_auc: 0.9581 - lr: 0.0010
# Epoch 124/150
# 9/9 [==============================] - ETA: 0s - loss: 0.0946 - accuracy: 0.9696 - auc: 0.9933
# Epoch 124: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0946 - accuracy: 0.9696 - auc: 0.9933 - val_loss: 0.2159 - val_accuracy: 0.9545 - val_auc: 0.9587 - lr: 0.0010
# Epoch 125/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.0740 - accuracy: 0.9688 - auc: 0.9958
# Epoch 125: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0745 - accuracy: 0.9696 - auc: 0.9969 - val_loss: 0.2173 - val_accuracy: 0.9545 - val_auc: 0.9587 - lr: 0.0010
# Epoch 126/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1028 - accuracy: 0.9848 - auc: 0.9953
# Epoch 126: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1028 - accuracy: 0.9848 - auc: 0.9953 - val_loss: 0.2169 - val_accuracy: 0.9545 - val_auc: 0.9587 - lr: 0.0010
# Epoch 127/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.0148 - accuracy: 1.0000 - auc: 1.0000
# Epoch 127: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 127: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1145 - accuracy: 0.9734 - auc: 0.9893 - val_loss: 0.2191 - val_accuracy: 0.9432 - val_auc: 0.9556 - lr: 0.0010
# Epoch 128/150
# 9/9 [==============================] - ETA: 0s - loss: 0.0627 - accuracy: 0.9886 - auc: 0.9988
# Epoch 128: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0627 - accuracy: 0.9886 - auc: 0.9988 - val_loss: 0.2329 - val_accuracy: 0.9318 - val_auc: 0.9537 - lr: 0.0010
# Epoch 129/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.0804 - accuracy: 0.9688 - auc: 1.0000
# Epoch 129: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1080 - accuracy: 0.9658 - auc: 0.9910 - val_loss: 0.2294 - val_accuracy: 0.9318 - val_auc: 0.9520 - lr: 0.0010
# Epoch 130/150
# 9/9 [==============================] - ETA: 0s - loss: 0.0794 - accuracy: 0.9772 - auc: 0.9961
# Epoch 130: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0794 - accuracy: 0.9772 - auc: 0.9961 - val_loss: 0.2188 - val_accuracy: 0.9432 - val_auc: 0.9556 - lr: 0.0010
# Epoch 131/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1532 - accuracy: 0.9354 - auc: 0.9872
# Epoch 131: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1532 - accuracy: 0.9354 - auc: 0.9872 - val_loss: 0.2063 - val_accuracy: 0.9659 - val_auc: 0.9565 - lr: 0.0010
# Epoch 132/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.0315 - accuracy: 1.0000 - auc: 1.0000
# Epoch 132: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 132: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0951 - accuracy: 0.9582 - auc: 0.9948 - val_loss: 0.2088 - val_accuracy: 0.9659 - val_auc: 0.9559 - lr: 0.0010
# Epoch 133/150
# 9/9 [==============================] - ETA: 0s - loss: 0.0897 - accuracy: 0.9658 - auc: 0.9955
# Epoch 133: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0897 - accuracy: 0.9658 - auc: 0.9955 - val_loss: 0.2182 - val_accuracy: 0.9545 - val_auc: 0.9568 - lr: 0.0010
# Epoch 134/150
# 8/9 [=========================>....] - ETA: 0s - loss: 0.0737 - accuracy: 0.9844 - auc: 0.9941
# Epoch 134: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0817 - accuracy: 0.9810 - auc: 0.9935 - val_loss: 0.2165 - val_accuracy: 0.9545 - val_auc: 0.9568 - lr: 0.0010
# Epoch 135/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1161 - accuracy: 0.9688 - auc: 0.9913
# Epoch 135: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0730 - accuracy: 0.9810 - auc: 0.9980 - val_loss: 0.2111 - val_accuracy: 0.9545 - val_auc: 0.9576 - lr: 0.0010
# Epoch 136/150
# 9/9 [==============================] - ETA: 0s - loss: 0.0792 - accuracy: 0.9772 - auc: 0.9943
# Epoch 136: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0792 - accuracy: 0.9772 - auc: 0.9943 - val_loss: 0.2060 - val_accuracy: 0.9659 - val_auc: 0.9587 - lr: 0.0010
# Epoch 137/150
# 9/9 [==============================] - ETA: 0s - loss: 0.0805 - accuracy: 0.9734 - auc: 0.9958
# Epoch 137: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 137: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0805 - accuracy: 0.9734 - auc: 0.9958 - val_loss: 0.2027 - val_accuracy: 0.9659 - val_auc: 0.9593 - lr: 0.0010
# Epoch 138/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.0505 - accuracy: 1.0000 - auc: 1.0000
# Epoch 138: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0688 - accuracy: 0.9848 - auc: 0.9955 - val_loss: 0.1963 - val_accuracy: 0.9659 - val_auc: 0.9604 - lr: 0.0010
# Epoch 139/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1735 - accuracy: 0.9688 - auc: 0.9843
# Epoch 139: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0751 - accuracy: 0.9734 - auc: 0.9952 - val_loss: 0.1929 - val_accuracy: 0.9659 - val_auc: 0.9531 - lr: 0.0010
# Epoch 140/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1266 - accuracy: 0.9506 - auc: 0.9879
# Epoch 140: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1266 - accuracy: 0.9506 - auc: 0.9879 - val_loss: 0.1939 - val_accuracy: 0.9659 - val_auc: 0.9576 - lr: 0.0010
# Epoch 141/150
# 9/9 [==============================] - ETA: 0s - loss: 0.0671 - accuracy: 0.9848 - auc: 0.9973
# Epoch 141: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0671 - accuracy: 0.9848 - auc: 0.9973 - val_loss: 0.2040 - val_accuracy: 0.9545 - val_auc: 0.9593 - lr: 0.0010
# Epoch 142/150
# 9/9 [==============================] - ETA: 0s - loss: 0.0804 - accuracy: 0.9658 - auc: 0.9978
# Epoch 142: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 142: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0804 - accuracy: 0.9658 - auc: 0.9978 - val_loss: 0.2137 - val_accuracy: 0.9432 - val_auc: 0.9595 - lr: 0.0010
# Epoch 143/150
# 9/9 [==============================] - ETA: 0s - loss: 0.0905 - accuracy: 0.9658 - auc: 0.9940
# Epoch 143: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0905 - accuracy: 0.9658 - auc: 0.9940 - val_loss: 0.2182 - val_accuracy: 0.9432 - val_auc: 0.9587 - lr: 0.0010
# Epoch 144/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.0272 - accuracy: 1.0000 - auc: 1.0000
# Epoch 144: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0765 - accuracy: 0.9772 - auc: 0.9963 - val_loss: 0.2314 - val_accuracy: 0.9432 - val_auc: 0.9587 - lr: 0.0010
# Epoch 145/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1086 - accuracy: 0.9734 - auc: 0.9940
# Epoch 145: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 19ms/step - loss: 0.1086 - accuracy: 0.9734 - auc: 0.9940 - val_loss: 0.2326 - val_accuracy: 0.9432 - val_auc: 0.9587 - lr: 0.0010
# Epoch 146/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.1111 - accuracy: 0.9688 - auc: 1.0000
# Epoch 146: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0767 - accuracy: 0.9772 - auc: 0.9979 - val_loss: 0.2297 - val_accuracy: 0.9432 - val_auc: 0.9581 - lr: 0.0010
# Epoch 147/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1197 - accuracy: 0.9772 - auc: 0.9887
# Epoch 147: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 147: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1197 - accuracy: 0.9772 - auc: 0.9887 - val_loss: 0.2256 - val_accuracy: 0.9545 - val_auc: 0.9581 - lr: 0.0010
# Epoch 148/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.0358 - accuracy: 1.0000 - auc: 1.0000
# Epoch 148: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1176 - accuracy: 0.9582 - auc: 0.9886 - val_loss: 0.2263 - val_accuracy: 0.9432 - val_auc: 0.9570 - lr: 0.0010
# Epoch 149/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9582 - auc: 0.9937
# Epoch 149: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1016 - accuracy: 0.9582 - auc: 0.9937 - val_loss: 0.2258 - val_accuracy: 0.9432 - val_auc: 0.9570 - lr: 0.0010
# Epoch 150/150
# 9/9 [==============================] - ETA: 0s - loss: 0.1193 - accuracy: 0.9544 - auc: 0.9860
# Epoch 150: val_loss did not improve from 0.18347
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1193 - accuracy: 0.9544 - auc: 0.9860 - val_loss: 0.2318 - val_accuracy: 0.9432 - val_auc: 0.9576 - lr: 0.0010

# %%
# Print the minimum loss values achieved during training and validation
print(f"Minimum training loss: {min(hist.history['loss'])}")
print(f"Minimum validation loss: {min(hist.history['val_loss'])}")

# Set the style of the plots
sns.set_style('darkgrid')

# Plot the training and validation loss over epochs
plt.plot(hist.history['loss'], label='Train')  # Training loss
plt.plot(hist.history['val_loss'], label='Eval')  # Validation loss

# Set the title and labels of the plot
plt.title('Loss Over Epochs')  # Title
plt.xlabel('Epochs')  # X-axis label
plt.ylabel('Loss')  # Y-axis label

# Show the legend and the plot
plt.legend()
plt.show()
# Out:
# Minimum training loss: 0.06273909658193588
# Minimum validation loss: 0.18347354233264923

# %%
# Print the maximum accuracy values achieved during training and validation
print(f"Maximum training accuracy: {max(hist.history['accuracy'])}")
print(f"Maximum validation accuracy: {max(hist.history['val_accuracy'])}")

# Set the style of the plots
sns.set_style('darkgrid')

# Plot the training and validation accuracy over epochs
plt.plot(hist.history['accuracy'], label='Train')  # Training accuracy
plt.plot(hist.history['val_accuracy'], label='Eval')  # Validation accuracy

# Set the title and labels of the plot
plt.title('Accuracy Over Epochs')  # Title
plt.xlabel('Epochs')  # X-axis label
plt.ylabel('Accuracy')  # Y-axis label

# Show the legend and the plot
plt.legend()
plt.show()
# Out:
# Maximum training accuracy: 0.9885931611061096
# Maximum validation accuracy: 0.9659090638160706

# %%
# Print the maximum AUC values achieved during training and validation
print(f"Maximum training AUC: {max(hist.history['auc'])}")
print(f"Maximum validation AUC: {max(hist.history['val_auc'])}")

# Set the style of the plots
sns.set_style('darkgrid')

# Plot the training and validation AUC over epochs
plt.plot(hist.history['auc'], label='Train')  # Training AUC
plt.plot(hist.history['val_auc'], label='Eval')  # Validation AUC

# Set the title and labels of the plot
plt.title('AUC Over Epochs')  # Title
plt.xlabel('Epochs')  # X-axis label
plt.ylabel('AUC')  # Y-axis label

# Show the legend and the plot
plt.legend()
plt.show()
# Out:
# Maximum training AUC: 0.9990242719650269
# Maximum validation AUC: 0.9670758843421936

# %%
#make dataframe of metrics
metrics_df = pd.DataFrame.from_dict(hist.history)
#save metrics to csv
metrics_df.to_csv('metrics.csv', index=False)
