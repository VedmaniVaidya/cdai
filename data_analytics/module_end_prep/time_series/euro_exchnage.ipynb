# %% [markdown]
# Do time series prediction on Euro exchange data
# Use arima model
# Select any one currency(for eg indian rupee or canadian dollar)
# 1. Make data stationary
# 2. Visualiize TS components
# 3. Prediction using ARIMA with two different
# Compare the two ARMIA models based on RMSE

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the data
df = pd.read_csv('./data/euro-daily-hist_1999_2022.csv')
df.head(10)
# Out:
#   Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 0   2023-05-26               1.6439           1.9558            5.3878
# 1   2023-05-25               1.6443           1.9558            5.3320
# 2   2023-05-24               1.6402           1.9558            5.3397
# 3   2023-05-23               1.6282           1.9558            5.3649
# 4   2023-05-22               1.6294           1.9558            5.4056
# 5   2023-05-19               1.6231           1.9558            5.3554
# 6   2023-05-18               1.6285           1.9558            5.3612
# 7   2023-05-17               1.6273           1.9558            5.3728
# 8   2023-05-16               1.6307           1.9558            5.3340
# 9   2023-05-15               1.6261           1.9558            5.3431
#
#   [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ] [Cypriot pound ]  \
# 0             1.4630         0.9707                   7.5874              NaN
# ...

# %%
df.columns
# Out:
# Index(['Period\Unit:', '[Australian dollar ]', '[Bulgarian lev ]',
#        '[Brazilian real ]', '[Canadian dollar ]', '[Swiss franc ]',
#        '[Chinese yuan renminbi ]', '[Cypriot pound ]', '[Czech koruna ]',
#        '[Danish krone ]', '[Estonian kroon ]', '[UK pound sterling ]',
#        '[Greek drachma ]', '[Hong Kong dollar ]', '[Croatian kuna ]',
#        '[Hungarian forint ]', '[Indonesian rupiah ]', '[Israeli shekel ]',
#        '[Indian rupee ]', '[Iceland krona ]', '[Japanese yen ]',
#        '[Korean won ]', '[Lithuanian litas ]', '[Latvian lats ]',
#        '[Maltese lira ]', '[Mexican peso ]', '[Malaysian ringgit ]',
#        '[Norwegian krone ]', '[New Zealand dollar ]', '[Philippine peso ]',
#        '[Polish zloty ]', '[Romanian leu ]', '[Russian rouble ]',
#        '[Swedish krona ]', '[Singapore dollar ]', '[Slovenian tolar ]',
#        '[Slovak koruna ]', '[Thai baht ]', '[Turkish lira ]', '[US dollar ]',
#        '[South African rand ]'],
# ...

# %%
df["Period\\Unit:"] = pd.to_datetime(df["Period\\Unit:"], format="%Y-%m-%d")
df = df.set_index("Period\\Unit:")
df.index.name = "Date"

# %%
#get all non numeric values from column [Indian rupee ]
df[df['[Indian rupee ]'] == '-']
# Out:
#            [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# Date
# 2012-05-01                    -                -                 -
# 2012-04-09                    -                -                 -
# 2012-04-06                    -                -                 -
# 2011-12-26                    -                -                 -
# 2011-04-25                    -                -                 -
# ...                         ...              ...               ...
# 2000-12-26                    -                -                 -
# 2000-12-25                    -                -                 -
# 2000-05-01                    -              NaN                 -
# 2000-04-24                    -              NaN                 -
# 2000-04-21                    -              NaN                 -
#
#            [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ]  \
# Date
# 2012-05-01                  -              -                        -
# ...

# %%
_temp = df[df['[Indian rupee ]'].str.isdigit()==False]

# %%
s1 = _temp['[Indian rupee ]'][0]

# %%
#check if s1 string is a number it can be a float containing decimal point
s1.isdigit()
# Out:
# False
